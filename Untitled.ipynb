# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler,minmax_scale
from sklearn.neighbors import KNeighborsClassifier
from pickle import load
from Data_preparation_Library import *
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import pandas as pd

# %%
X_dtm = np.load('prepared_data/X_dtm_aug.npy')
y_dtm = np.load('prepared_data/y_dtm_aug.npy')

# %%
X_raw = np.load('X_test_raw.npy')
y_raw = np.load('y_test_raw.npy')

# %%
X_mean = np.load('mean_std.npy')[0]
X_std = np.load('mean_std.npy')[1]
X = []
for x in tqdm(X_raw):
    X.append((x-X_mean)/X_std)
X_raw_new = np.array(X)

# %%
pd.DataFrame(X_dtm[10000]).plot(figsize=(16,5),legend=True)
pd.DataFrame(X_raw[1000]).plot(figsize=(16,5),legend=True)
pd.DataFrame(X_raw_new[1000]).plot(figsize=(16,5),legend=True)
# Out:
# <AxesSubplot:>
