# %% [markdown]
# # DTM  Classifier

# %%
import pandas as pd
from Data_preparation_Library import *
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from time import time
from sklearn.model_selection import train_test_split
from keras.models import load_model
from random import choice
from scipy import signal
from pickle import load

# %% [markdown]
# ## Data Analysis Section

# %%
file = 'Subjects/Fazil/day_04_14_21/computed_Hammer02.csv'
emg_labels = ['EMG1','EMG2','EMG3','EMG4','EMG5','EMG6','EMG7','EMG8']
angle_lables = ['Pronation_Angle','Flexion_Angle',  'Radial_Angle','Elbow_Joint_Angle']
df = pd.read_csv(file,index_col=0)
df[angle_lables].plot(figsize=(16,5),title=file,grid=True,xticks=np.linspace(0,len(df),5))
# Out:
# <AxesSubplot:title={'center':'Subjects/Fazil/day_04_14_21/computed_Hammer02.csv'}>

# %%
X, y = prep_data_DTM(df,400,interval=40,Normalize=False,plot=True,angle_thresh=0.008,rms=False)
X.shape
# Out:
# 0 -> 66.54676258992805 %
# 1 -> 8.776978417266188 %
# 2 -> 24.676258992805757 %
# (1390, 400, 8)

# %% [markdown]
# ## File Name Generation

# %%
files = []

# %%
path = 'Subjects/Fazil/day_04_24_21'
# trial_names = ['Screw'] # 'Bulb','Hammer' ,'Cup','Screw'
trial_names = ['Bulb','Hammer' ,'Cup','Screw'] #,
for exp in trial_names:
    for i in range(3):
        if(i==0):
            files.append(path+'/computed_'+exp+'.csv')
        else:
            files.append(path+'/computed_'+exp+'0'+str(i)+'.csv')
files
# Out:
# ['Subjects/Fazil/day_04_24_21/computed_Bulb.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Bulb01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Bulb02.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Hammer.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Hammer01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Hammer02.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup02.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw02.csv']

# %%
path = 'Subjects/Fazil/day_04_14_21'
trial_names = ['Screw'] # 'Bulb','Hammer' ,'Cup','Screw'
trial_names = ['Bulb','Hammer' ,'Cup','Screw']
for exp in trial_names:
    for i in range(3):
        if(i==0):
            files.append(path+'/computed_'+exp+'.csv')
        else:
            files.append(path+'/computed_'+exp+'0'+str(i)+'.csv')
files
# Out:
# ['Subjects/Fazil/day_04_24_21/computed_Bulb.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Bulb01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Bulb02.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Hammer.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Hammer01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Hammer02.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup02.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw02.csv',
#  'Subjects/Fazil/day_04_14_21/computed_Bulb.csv',
#  'Subjects/Fazil/day_04_14_21/computed_Bulb01.csv',
#  'Subjects/Fazil/day_04_14_21/computed_Bulb02.csv',
#  'Subjects/Fazil/day_04_14_21/computed_Hammer.csv',
#  'Subjects/Fazil/day_04_14_21/computed_Hammer01.csv',
#  'Subjects/Fazil/day_04_14_21/computed_Hammer02.csv',
#  'Subjects/Fazil/day_04_14_21/computed_Cup.csv',
#  'Subjects/Fazil/day_04_14_21/computed_Cup01.csv',
#  'Subjects/Fazil/day_04_14_21/computed_Cup02.csv']

# %%
files_df = []
for file in files:
    files_df.append(pd.read_csv(file,index_col=0))

# %%
def filter_df(files_df,order=1,cf=50,fs=2000):
    b,a = signal.butter(1, 50,fs=fs)
    for i in range(len(files_df)):
        emg_df = pd.DataFrame(columns=emg_labels)
        for labels in emg_labels:
            emg_df[labels] = signal.lfilter(b, a,files_df[i][labels])
        files_df[i][emg_labels] = np.array(emg_df)
    return files_df

# %%
emg_labels = ['EMG1','EMG2','EMG3','EMG4','EMG5','EMG6','EMG7','EMG8']

# %%
files_df = filter_df(files_df)

# %% [markdown]
# ## Data Augumentation

# %% [markdown]
# ### Gausian Noise

# %%
files_df_gausian = []
for df in tqdm(files_df):
    snr = choice(np.linspace(60,90,5))
    emg_array = np.array(add__Gausian_noise(df[emg_labels],snr))
    df[emg_labels] = emg_array
    files_df_gausian.append(df)

files_df = files_df+files_df_gausian
len(files_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# 44

# %% [markdown]
# ### Rearrange

# %%
files_df_rearrange = []
for df in tqdm(files_df):
    df[emg_labels] = df[scrambled(emg_labels)]
    files_df_rearrange.append(df) 
    
files_df = files_df+files_df_rearrange
len(files_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# 36

# %% [markdown]
# ## Data Prep Pipeline

# %% [markdown]
# ### Parameters

# %%
window = 400
interval = 4
Normalize = False
rms = False
angle_thresh_DTM = 0.008

# %%
X_dtm, y_dtm = multiple_prep_data_DTM(files_df,
                                      window,
                                      interval,
                                      Normalize,
                                      rms,
                                      angle_thresh_DTM)
print(X_dtm.shape,y_dtm.shape)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# (189300, 400, 8) (189300, 3)

# %%
np.save('X_test_raw',X_dtm)
np.save('y_test_raw',y_dtm)

# %% [markdown]
# ## Whole Normalize

# %% [markdown]
# ‘‘time window normalization’’ (i.e., subtracting to
# each time window the mean and dividing it by the standard
# deviation) and ‘‘normalization based on training data’’ (i.e.,
# subtracting to all the time windows the training data mean and
# dividing them by the training data standard deviation).

# %%
# X = X_dtm.reshape((X_dtm.shape[0]*X_dtm.shape[1],X_dtm.shape[2]))
# old_range = [X.min(),X.max()]
# new_range = [-1,1]
# scale_param = np.array([old_range,new_range])
# X = map_it(X,old_range,new_range)
# np.save('scale_param',scale_param)
# X = min_max(X)
# X = norm(X)
# X_dtm = X.reshape(X_dtm.shape)

# X = []
# for x in tqdm(X_dtm):
#     X.append(map_it(x,
#                     (x.min(),x.max()),
#                     (-1,1)))
# X_dtm = np.array(X)

# %%
def variance(data, ddof=0):
    n = len(data)
    mean = sum(data) / n
    return sum((x - mean) ** 2 for x in data) / (n - ddof)

# %%
X_mean = np.zeros(X_dtm[0].shape)
for x in X_dtm:
    X_mean = X_mean + x
X_mean = X_mean/X_dtm.shape[0]
X_std = np.sqrt(variance(X_dtm))
np.save('mean_std',np.array([X_mean,X_std]))

# %%
X = []
for x in tqdm(X_dtm):
    X.append((x-X_mean)/X_std)
X_dtm = np.array(X)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=75720.0), HTML(value='')))

# %%
X = []
for x in tqdm(X_dtm):
    arr = x.copy()
    arr = (arr - arr.mean())/np.sqrt(variance(arr))
    X.append(arr)
X_dtm = np.array(X)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=95424.0), HTML(value='')))

# %%
np.save('prepared_data/X_dtm_aug',X_dtm)
np.save('prepared_data/y_dtm_aug',y_dtm)

# %%
X_dtm = np.load('prepared_data/X_dtm_aug.npy')
y_dtm = np.load('prepared_data/y_dtm_aug.npy')

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dtm, y_dtm,test_size=0.2)
for data in [X_train, X_test, y_train, y_test]:
    print(data.shape)
# Out:
# (151440, 400, 8)
# (37860, 400, 8)
# (151440, 3)
# (37860, 3)

# %%
X_test__, X_val, y_test__, y_val = train_test_split(X_test, y_test,test_size=0.4)
for data in [X_test, X_val, y_test, y_val]:
    print(data.shape)
# Out:
# (37860, 400, 8)
# (15144, 400, 8)
# (37860, 3)
# (15144, 3)

# %%
y_true = []
for d in y_test:
    idx = list(d).index(1)
    y_true.append(idx)

# %%
def count(y):
    s0 = 0
    s1 = 0
    s2 = 0
    for arr in y:
        if arr[0]==1:
            s0 = s0+1
        if arr[1]==1:
            s1 = s1+1
        if arr[2]==1:
            s2 = s2+1
    ls = [s0,s1,s2]
    for i in range(3):
        print(i,'-',ls[i],'[',ls[i]*100/len(y),'%]')

# %%
print(count(y_train))
print(count(y_test))
# Out:
# 0 - 76781 [ 50.700607501320654 %]
# 1 - 20385 [ 13.460776545166402 %]
# 2 - 54274 [ 35.83861595351294 %]
# None
# 0 - 19110 [ 50.47543581616482 %]
# 1 - 5067 [ 13.38351822503962 %]
# 2 - 13683 [ 36.141045958795566 %]
# None

# %% [markdown]
# # InceptionTime Trainer

# %%
import numpy as np
import sklearn
import pandas as pd
import sys
import subprocess
import tensorflow as tf
from InceptionTime.classifiers.inception import Classifier_INCEPTION

# %% [markdown]
# ## Build Model

# %%
clf = Classifier_INCEPTION('', (X_train.shape[1],X_train.shape[2]),nb_classes=3,
                            verbose=True,batch_size=512,nb_epochs=50,nb_filters=32,
                            depth=6, kernel_size=11)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 400, 8)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 400, 32)      256         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 400, 8)       0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 400, 32)      10240       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 400, 32)      5120        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 400, 32)      2048        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 400, 32)      256         max_pooling1d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 400, 128)     0           conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 400, 128)     512         concatenate[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 400, 128)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 400, 32)      4096        activation[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 400, 128)     0           activation[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 400, 32)      10240       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 400, 32)      5120        conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 400, 32)      2048        conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 400, 32)      4096        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 400, 128)     0           conv1d_6[0][0]
#                                                                  conv1d_7[0][0]
#                                                                  conv1d_8[0][0]
#                                                                  conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 400, 128)     512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 400, 128)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 400, 32)      4096        activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 400, 128)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 400, 32)      10240       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 400, 32)      5120        conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 400, 32)      2048        conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 400, 32)      4096        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 400, 128)     0           conv1d_11[0][0]
#                                                                  conv1d_12[0][0]
#                                                                  conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 400, 128)     1024        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 400, 128)     512         concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 400, 128)     512         conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 400, 128)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 400, 128)     0           batch_normalization_3[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 400, 128)     0           add[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 400, 32)      4096        activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 400, 128)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 400, 32)      10240       conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 400, 32)      5120        conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 400, 32)      2048        conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 400, 32)      4096        max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 400, 128)     0           conv1d_17[0][0]
#                                                                  conv1d_18[0][0]
#                                                                  conv1d_19[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 400, 128)     512         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 400, 128)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 400, 32)      4096        activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 400, 128)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 400, 32)      10240       conv1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 400, 32)      5120        conv1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 400, 32)      2048        conv1d_21[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 400, 32)      4096        max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 400, 128)     0           conv1d_22[0][0]
#                                                                  conv1d_23[0][0]
#                                                                  conv1d_24[0][0]
#                                                                  conv1d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 400, 128)     512         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 400, 128)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 400, 32)      4096        activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 400, 128)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 400, 32)      10240       conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 400, 32)      5120        conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 400, 32)      2048        conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 400, 32)      4096        max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 400, 128)     0           conv1d_27[0][0]
#                                                                  conv1d_28[0][0]
#                                                                  conv1d_29[0][0]
#                                                                  conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 400, 128)     16384       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 400, 128)     512         concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 400, 128)     512         conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 400, 128)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 400, 128)     0           batch_normalization_7[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 400, 128)     0           add_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 128)          0           activation_7[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            387         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 167,811
# Trainable params: 165,763
# Non-trainable params: 2,048
# __________________________________________________________________________________________________

# %%
df_metrics = clf.fit(X_train, y_train, X_test, y_test, y_true,plot_test_acc=True)
# Out:
# Epoch 1/50
# 296/296 [==============================] - 118s 398ms/step - loss: 0.1205 - accuracy: 0.9547 - val_loss: 0.2324 - val_accuracy: 0.9086 - lr: 0.0010
# Epoch 2/50
# 296/296 [==============================] - 131s 444ms/step - loss: 0.1135 - accuracy: 0.9567 - val_loss: 0.2373 - val_accuracy: 0.9151 - lr: 0.0010
# Epoch 3/50
# 296/296 [==============================] - 134s 452ms/step - loss: 0.1136 - accuracy: 0.9567 - val_loss: 0.2929 - val_accuracy: 0.8936 - lr: 0.0010
# Epoch 4/50
# 296/296 [==============================] - 135s 457ms/step - loss: 0.1107 - accuracy: 0.9576 - val_loss: 0.6350 - val_accuracy: 0.8177 - lr: 0.0010
# Epoch 5/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.1080 - accuracy: 0.9584 - val_loss: 0.3073 - val_accuracy: 0.8977 - lr: 0.0010
# Epoch 6/50
# 296/296 [==============================] - 135s 457ms/step - loss: 0.1065 - accuracy: 0.9594 - val_loss: 0.2429 - val_accuracy: 0.9077 - lr: 0.0010
# Epoch 7/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.1037 - accuracy: 0.9600 - val_loss: 0.8437 - val_accuracy: 0.7586 - lr: 0.0010
# Epoch 8/50
# 296/296 [==============================] - 135s 457ms/step - loss: 0.1005 - accuracy: 0.9616 - val_loss: 0.2405 - val_accuracy: 0.9160 - lr: 0.0010
# Epoch 9/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0979 - accuracy: 0.9624 - val_loss: 0.3111 - val_accuracy: 0.8941 - lr: 0.0010
# Epoch 10/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0947 - accuracy: 0.9638 - val_loss: 0.2402 - val_accuracy: 0.9164 - lr: 0.0010
# Epoch 11/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0929 - accuracy: 0.9644 - val_loss: 0.2336 - val_accuracy: 0.9170 - lr: 0.0010
# Epoch 12/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0886 - accuracy: 0.9669 - val_loss: 0.2245 - val_accuracy: 0.9188 - lr: 0.0010
# Epoch 13/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0859 - accuracy: 0.9671 - val_loss: 0.2883 - val_accuracy: 0.9022 - lr: 0.0010
# Epoch 14/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0842 - accuracy: 0.9682 - val_loss: 0.2534 - val_accuracy: 0.9132 - lr: 0.0010
# Epoch 15/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0803 - accuracy: 0.9698 - val_loss: 0.3882 - val_accuracy: 0.8710 - lr: 0.0010
# Epoch 16/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0782 - accuracy: 0.9707 - val_loss: 0.2140 - val_accuracy: 0.9282 - lr: 0.0010
# Epoch 17/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0762 - accuracy: 0.9718 - val_loss: 0.2881 - val_accuracy: 0.9103 - lr: 0.0010
# Epoch 18/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0718 - accuracy: 0.9734 - val_loss: 0.1575 - val_accuracy: 0.9421 - lr: 0.0010
# Epoch 19/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0724 - accuracy: 0.9728 - val_loss: 0.3382 - val_accuracy: 0.8861 - lr: 0.0010
# Epoch 20/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0701 - accuracy: 0.9742 - val_loss: 0.2160 - val_accuracy: 0.9204 - lr: 0.0010
# Epoch 21/50
# 296/296 [==============================] - 135s 457ms/step - loss: 0.0675 - accuracy: 0.9749 - val_loss: 0.2252 - val_accuracy: 0.9184 - lr: 0.0010
# Epoch 22/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0664 - accuracy: 0.9749 - val_loss: 0.5200 - val_accuracy: 0.8648 - lr: 0.0010
# Epoch 23/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0628 - accuracy: 0.9771 - val_loss: 0.2036 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 24/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0638 - accuracy: 0.9763 - val_loss: 0.2882 - val_accuracy: 0.8990 - lr: 0.0010
# Epoch 25/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0622 - accuracy: 0.9768 - val_loss: 0.1996 - val_accuracy: 0.9293 - lr: 0.0010
# Epoch 26/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0584 - accuracy: 0.9790 - val_loss: 0.3457 - val_accuracy: 0.8862 - lr: 0.0010
# Epoch 27/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0571 - accuracy: 0.9790 - val_loss: 0.4034 - val_accuracy: 0.8624 - lr: 0.0010
# Epoch 28/50
# 296/296 [==============================] - 135s 457ms/step - loss: 0.0548 - accuracy: 0.9799 - val_loss: 0.1412 - val_accuracy: 0.9505 - lr: 0.0010
# Epoch 29/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0540 - accuracy: 0.9799 - val_loss: 0.2488 - val_accuracy: 0.9181 - lr: 0.0010
# Epoch 30/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0540 - accuracy: 0.9801 - val_loss: 0.4959 - val_accuracy: 0.8884 - lr: 0.0010
# Epoch 31/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0522 - accuracy: 0.9807 - val_loss: 0.6193 - val_accuracy: 0.8489 - lr: 0.0010
# Epoch 32/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0503 - accuracy: 0.9816 - val_loss: 0.1569 - val_accuracy: 0.9474 - lr: 0.0010
# Epoch 33/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0504 - accuracy: 0.9818 - val_loss: 0.4384 - val_accuracy: 0.8612 - lr: 0.0010
# Epoch 34/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0485 - accuracy: 0.9823 - val_loss: 0.4533 - val_accuracy: 0.8710 - lr: 0.0010
# Epoch 35/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0459 - accuracy: 0.9833 - val_loss: 0.1452 - val_accuracy: 0.9496 - lr: 0.0010
# Epoch 36/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0460 - accuracy: 0.9831 - val_loss: 0.1949 - val_accuracy: 0.9357 - lr: 0.0010
# Epoch 37/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0472 - accuracy: 0.9828 - val_loss: 0.2382 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 38/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0432 - accuracy: 0.9842 - val_loss: 0.1351 - val_accuracy: 0.9539 - lr: 0.0010
# Epoch 39/50
# 296/296 [==============================] - 135s 455ms/step - loss: 0.0428 - accuracy: 0.9845 - val_loss: 0.3031 - val_accuracy: 0.9059 - lr: 0.0010
# Epoch 40/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0438 - accuracy: 0.9843 - val_loss: 0.1390 - val_accuracy: 0.9533 - lr: 0.0010
# Epoch 41/50
# 296/296 [==============================] - 135s 457ms/step - loss: 0.0415 - accuracy: 0.9849 - val_loss: 0.1034 - val_accuracy: 0.9644 - lr: 0.0010
# Epoch 42/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0404 - accuracy: 0.9855 - val_loss: 0.2823 - val_accuracy: 0.9085 - lr: 0.0010
# Epoch 43/50
# 296/296 [==============================] - 135s 457ms/step - loss: 0.0412 - accuracy: 0.9853 - val_loss: 0.1153 - val_accuracy: 0.9612 - lr: 0.0010
# Epoch 44/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0377 - accuracy: 0.9865 - val_loss: 0.1480 - val_accuracy: 0.9493 - lr: 0.0010
# Epoch 45/50
# 296/296 [==============================] - 135s 457ms/step - loss: 0.0396 - accuracy: 0.9856 - val_loss: 0.1446 - val_accuracy: 0.9506 - lr: 0.0010
# Epoch 46/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0376 - accuracy: 0.9866 - val_loss: 0.1634 - val_accuracy: 0.9475 - lr: 0.0010
# Epoch 47/50
# 296/296 [==============================] - 135s 456ms/step - loss: 0.0377 - accuracy: 0.9865 - val_loss: 0.1750 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 48/50
# 296/296 [==============================] - 134s 454ms/step - loss: 0.0376 - accuracy: 0.9865 - val_loss: 0.1123 - val_accuracy: 0.9623 - lr: 0.0010
# Epoch 49/50
# 296/296 [==============================] - 134s 454ms/step - loss: 0.0352 - accuracy: 0.9874 - val_loss: 0.1239 - val_accuracy: 0.9573 - lr: 0.0010
# Epoch 50/50
# 296/296 [==============================] - 134s 451ms/step - loss: 0.0370 - accuracy: 0.9868 - val_loss: 0.1410 - val_accuracy: 0.9544 - lr: 0.0010

# %%
clf.model = load_model('models/DTM_400_raw.hdf5')

# %%
best_model = load_model('best_model.hdf5')
best_model.save('models/DTM_{}_raw.hdf5'.format(window))

# %%
best_model = load_model('best_model.hdf5')
best_model.save('models/DTM_{}_aug_tw.hdf5'.format(window))

# %%
system_sleep()

# %% [markdown]
# ## Testing

# %%
model = load_model('models/DTM_{}_raw.hdf5'.format(window))

# %%
# mx_scaler = load(open('min_max.pkl', 'rb'))
# std_scaler = load(open('standard_scaler.pkl', 'rb'))

# X = mx_scaler.transform(X)
# X = std_scaler.transform(X)
X = X_dtm.reshape(X_dtm.shape[0]*X_dtm.shape[1],X_dtm.shape[2])
scale_param = np.load('scale_param.npy')
print(scale_param)
X = map_it(X,scale_param[0],scale_param[1])
X_dtm = X.reshape(X_dtm.shape)
# Out:
# [[-2.50412559  1.50388032]
#  [-1.          1.        ]]

# %%
X_mean = np.load('mean_std.npy')[0]
X_std = np.load('mean_std.npy')[1]

# %%
X = []
for x in tqdm(X_dtm):
    X.append((x-X_mean)/X_std)
X_dtm = np.array(X)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9160.0), HTML(value='')))

# %%
model.evaluate(X_val,y_val)

# %% [markdown]
# ## Plot Results

# %%
# %matplotlib inline
metrics_df = pd.read_csv('df_metrics.csv')
best_model_df = pd.read_csv('df_best_model.csv')
history_df = pd.read_csv('history.csv')

# %%
metrics_df
# Out:
#    precision  accuracy    recall     duration
# 0    0.88665  0.839564  0.755708  4423.145344

# %%
history_df[['accuracy','val_accuracy']].plot(figsize=(14,8),title='Accuracy',grid=True,fontsize=15)
history_df[['loss','val_loss']].plot(figsize=(14,8),title='Loss',grid=True,fontsize=15)
# Out:
# <AxesSubplot:title={'center':'Loss'}>
