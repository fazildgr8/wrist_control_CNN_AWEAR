# %% [markdown]
# # CNN Regression Model

# %%
import pandas as pd
from Data_preparation_Library import *
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from time import time
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from random import choice
from scipy import signal
from pickle import load,dump
import math
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Sample

# %%
file = 'Subjects/Fazil/day_04_24_21/computed_Bulb.csv'
emg_labels = ['EMG1','EMG2','EMG3','EMG4','EMG5','EMG6','EMG7','EMG8']
angle_lables = ['Flexion_Angle'] # 'Pronation_Angle','Flexion_Angle',  'Radial_Angle','Elbow_Joint_Angle'
df = pd.read_csv(file,index_col=0)
df[angle_lables].plot(figsize=(16,5),title=file,grid=True,xticks=np.linspace(0,len(df),5))

arr = np.diff([0]+list(df['Pronation_Angle']))
# arr = arr/df.index
b,a = signal.butter(1, 1,fs=2000)
arr = signal.lfilter(b, a,arr)
pd.DataFrame(arr[1000:]).plot(figsize=(16,5),title='Velocity',grid=True,xticks=np.linspace(0,len(df),5))
# Out:
# <AxesSubplot:title={'center':'Velocity'}>

# %% [markdown]
# ## Prep Data

# %%
window = 400

# %%
files = []
subjects = ['Fazil/day_04_24_21','Nikhil/day_05_13_21'] #'Fazil/day_04_14_21'
for subj in subjects:
    path = 'Subjects/'+subj
    # trial_names = ['Bulb','Hammer'] # 'Bulb','Hammer' ,'Cup','Screw'
    trial_names = ['Bulb','Hammer' ,'Cup','Screw'] #,
    for exp in trial_names:
        for i in range(3):
            if(i==0):
                files.append(path+'/computed_'+exp+'.csv')
            else:
                files.append(path+'/computed_'+exp+'0'+str(i)+'.csv')
files
# Out:
# ['Subjects/Fazil/day_04_24_21/computed_Bulb.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Bulb01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Bulb02.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Hammer.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Hammer01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Hammer02.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup02.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw02.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Bulb.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Bulb01.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Bulb02.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Hammer.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Hammer01.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Hammer02.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Cup.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Cup01.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Cup02.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Screw.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Screw01.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Screw02.csv']

# %%
files = files[1:]

# %%
files_df = []
for file in files:
    files_df.append(pd.read_csv(file,index_col=0))

# %%
files_df = filter_df(files_df)

# %%
X, y = multiple_prep_data_velocity(files_df,window,interval=10,Normalize=False,rms=False,angle_label ='Flexion_Angle')
X.shape
# Out:
# HBox(children=(FloatProgress(value=0.0, max=23.0), HTML(value='')))
# (142280, 400, 8)

# %% [markdown]
# ## Time Window Normalize

# %%
X_mean = np.zeros(X[0].shape)
for x in X:
    X_mean = X_mean + x
X_mean = X_mean/X.shape[0]
X_std = np.sqrt(variance(X))
np.save('mean_std',np.array([X_mean,X_std]))

# %%
X_new = []
for x in tqdm(X):
    X_new.append((x-X_mean)/X_std)
X = np.array(X_new)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=142280.0), HTML(value='')))

# %% [markdown]
# ## Test Train Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)
for data in [X_train, X_test, y_train, y_test]:
    print(data.shape)
# Out:
# (113824, 400, 8)
# (28456, 400, 8)
# (113824, 1)
# (28456, 1)

# %% [markdown]
# # Neural Network Regression

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow import keras
n_outputs = 1

# %%
n_outputs = 1
in_shape = (X.shape[1],X.shape[2])

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=in_shape))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
# model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
# model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))

model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
# model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
# model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
# model.add(Dense(10,activation='relu'))
model.add(Dense(n_outputs))

model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 398, 64)           1600
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 396, 64)           12352
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 394, 64)           12352
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 392, 64)           12352
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 392, 64)           0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 390, 16)           3088
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 390, 16)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6240)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6241
# =================================================================
# Total params: 47,985
# Trainable params: 47,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = load_model('models/flexex_velocity_model_{}.hdf5'.format(window))

# %%
cnn_history=model.fit(X_train,y_train,epochs = 25,batch_size = 2500,validation_data = (X_test,y_test) )
# Out:
# Epoch 1/25
# 46/46 [==============================] - 11s 228ms/step - loss: 0.3692 - val_loss: 0.3249
# Epoch 2/25
# 46/46 [==============================] - 10s 227ms/step - loss: 0.3316 - val_loss: 0.3117
# Epoch 3/25
# 46/46 [==============================] - 11s 229ms/step - loss: 0.3363 - val_loss: 0.4074
# Epoch 4/25
# 46/46 [==============================] - 11s 230ms/step - loss: 0.3207 - val_loss: 0.3989
# Epoch 5/25
# 46/46 [==============================] - 11s 231ms/step - loss: 0.3221 - val_loss: 0.2760
# Epoch 6/25
# 46/46 [==============================] - 11s 233ms/step - loss: 0.3056 - val_loss: 0.3901
# Epoch 7/25
# 46/46 [==============================] - 11s 233ms/step - loss: 0.2972 - val_loss: 0.4613
# Epoch 8/25
# 46/46 [==============================] - 11s 235ms/step - loss: 0.3020 - val_loss: 0.2752
# Epoch 9/25
# 46/46 [==============================] - 12s 255ms/step - loss: 0.2872 - val_loss: 0.2942
# Epoch 10/25
# 46/46 [==============================] - 12s 266ms/step - loss: 0.2752 - val_loss: 0.2389
# Epoch 11/25
# 46/46 [==============================] - 13s 280ms/step - loss: 0.2778 - val_loss: 0.3703
# Epoch 12/25
# 46/46 [==============================] - 13s 290ms/step - loss: 0.2628 - val_loss: 0.2263
# Epoch 13/25
# 46/46 [==============================] - 13s 290ms/step - loss: 0.2807 - val_loss: 0.3666
# Epoch 14/25
# 46/46 [==============================] - 13s 289ms/step - loss: 0.2558 - val_loss: 0.5868
# Epoch 15/25
# 46/46 [==============================] - 13s 288ms/step - loss: 0.2736 - val_loss: 0.2608
# Epoch 16/25
# 46/46 [==============================] - 13s 277ms/step - loss: 0.2480 - val_loss: 0.2483
# Epoch 17/25
# 46/46 [==============================] - 13s 285ms/step - loss: 0.2297 - val_loss: 0.2639
# Epoch 18/25
# 46/46 [==============================] - 13s 288ms/step - loss: 0.2469 - val_loss: 0.2006
# Epoch 19/25
# 46/46 [==============================] - 13s 280ms/step - loss: 0.2358 - val_loss: 0.1960
# Epoch 20/25
# 46/46 [==============================] - 14s 295ms/step - loss: 0.2286 - val_loss: 0.2355
# Epoch 21/25
# 46/46 [==============================] - 14s 295ms/step - loss: 0.2133 - val_loss: 0.2257
# Epoch 22/25
# 46/46 [==============================] - 13s 292ms/step - loss: 0.2126 - val_loss: 0.2463
# Epoch 23/25
# 46/46 [==============================] - 13s 291ms/step - loss: 0.2206 - val_loss: 0.2051
# Epoch 24/25
# 46/46 [==============================] - 13s 293ms/step - loss: 0.2068 - val_loss: 0.2608
# Epoch 25/25
# 46/46 [==============================] - 14s 296ms/step - loss: 0.2136 - val_loss: 0.1628

# %%
model.save('models/flexex_velocity_model_{}.hdf5'.format(window))

# %%
plot_model(cnn_history)

# %%
import matplotlib.pyplot as plt
def plot_model(history):
#     plt.figure(figsize=(10,6))
#     plt.plot(history.history['root_mean_squared_error'][1:])
#     plt.plot(history.history['val_root_mean_squared_error'][1:])
#     plt.title('Model RMSE',size=20)
#     plt.ylabel('RMSE Loss',size=15)
#     plt.xlabel('Epochs', size=15)
#     plt.legend(['Training', 'Testing'], loc='best')
#     plt.show()
    
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss',size=20)
    plt.ylabel('Loss',size=15)
    plt.xlabel('Epochs',size=15)
    plt.legend(['Training', 'Testing'], loc='best')
    plt.show()

# %% [markdown]
# ## Model Testing

# %%
file = 'Subjects/Fazil/day_04_24_21/computed_Bulb.csv'
df = pd.read_csv(file,index_col=0)

# %%
X, y = prep_data_velocity(df,window,interval=10,Normalize=False,rms=False,angle_label ='Flexion_Angle')

# %%
X_mean = np.load('mean_std.npy')[0]
X_std = np.load('mean_std.npy')[1]
X_new = []
for x in tqdm(X):
    X_new.append((x-X_mean)/X_std)
X = np.array(X_new)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9160.0), HTML(value='')))

# %%
pred = model.predict(X)

# %%
plt.figure(figsize=(16,5))
plt.plot(pred)
plt.plot(y)
plt.title('True Velocity Vs Predicted Velocity',size=20)
plt.ylabel('Ang Velocity',size=15)
plt.xlabel('Time', size=15)
plt.legend(['Predicted', 'True'], loc='best')
plt.show()

# %%
print('Pearson Correlation Coefficient -',pearsonr(y.flatten(),pred.flatten()))
print('RMSE Score -',mean_squared_error(y,pred,squared=False))
# Out:
# Pearson Correlation Coefficient - (0.24860037962290601, 4.5816548347154695e-129)
# RMSE Score - 1.0633753596500282
