# %% [markdown]
# # CNN Regression Model

# %%
import pandas as pd
from Data_preparation_Library import *
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from time import time
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from random import choice
from scipy import signal
from pickle import load,dump
import math
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Sample

# %%
file = 'Subjects/Fazil/day_04_24_21/computed_Hammer.csv'
emg_labels = ['EMG1','EMG2','EMG3','EMG4','EMG5','EMG6','EMG7','EMG8']
angle_lables = ['Flexion_Angle'] # 'Pronation_Angle','Flexion_Angle',  'Radial_Angle','Elbow_Joint_Angle'
df = pd.read_csv(file,index_col=0)
df[angle_lables].plot(figsize=(16,5),title=file,grid=True,xticks=np.linspace(0,len(df),5))

arr = np.diff([0]+list(df['Flexion_Angle']))
# arr = arr/df.index
b,a = signal.butter(1, 1,fs=2000)
arr = signal.lfilter(b, a,arr)
sclr = StandardScaler()
arr = sclr.fit_transform(arr.reshape(-1,1))
pd.DataFrame(arr[1000:]).plot(figsize=(16,5),title='Velocity',grid=True,xticks=np.linspace(0,len(df),5))
# Out:
# <AxesSubplot:title={'center':'Velocity'}>

# %% [markdown]
# ## Prep Data

# %%
window = 400

# %%
files = []
subjects = ['Fazil/day_04_24_21','Nikhil/day_05_13_21'] #'Fazil/day_04_14_21'
for subj in subjects:
    path = 'Subjects/'+subj
    # trial_names = ['Bulb','Hammer'] # 'Bulb','Hammer' ,'Cup','Screw'
    trial_names = ['Bulb','Hammer' ,'Cup','Screw'] #,
    for exp in trial_names:
        for i in range(3):
            if(i==0):
                files.append(path+'/computed_'+exp+'.csv')
            else:
                files.append(path+'/computed_'+exp+'0'+str(i)+'.csv')
files = files[:2]+files[4:]
files
# Out:
# ['Subjects/Fazil/day_04_24_21/computed_Bulb.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Bulb01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Hammer01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Hammer02.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Cup02.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw01.csv',
#  'Subjects/Fazil/day_04_24_21/computed_Screw02.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Bulb.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Bulb01.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Bulb02.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Hammer.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Hammer01.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Hammer02.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Cup.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Cup01.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Cup02.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Screw.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Screw01.csv',
#  'Subjects/Nikhil/day_05_13_21/computed_Screw02.csv']

# %%
files_df = []
for file in files:
    files_df.append(pd.read_csv(file,index_col=0))

# %%
files_df = filter_df(files_df)

# %%
X, y = multiple_prep_data_velocity(files_df,window,interval=10,Normalize=False,rms=False,angle_label ='Flexion_Angle')
X.shape
# Out:
# HBox(children=(FloatProgress(value=0.0, max=22.0), HTML(value='')))
# (136920, 400, 8)

# %% [markdown]
# ## Time Window Normalize

# %%
X_mean = np.zeros(X[0].shape)
for x in X:
    X_mean = X_mean + x
X_mean = X_mean/X.shape[0]
X_std = np.sqrt(variance(X))
np.save('mean_std_flexex',np.array([X_mean,X_std]))

# %%
X_new = []
for x in tqdm(X):
    X_new.append((x-X_mean)/X_std)
X = np.array(X_new)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=136920.0), HTML(value='')))

# %% [markdown]
# ## Test Train Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)
for data in [X_train, X_test, y_train, y_test]:
    print(data.shape)
# Out:
# (109536, 400, 8)
# (27384, 400, 8)
# (109536, 1)
# (27384, 1)

# %% [markdown]
# # Neural Network Regression

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow import keras
n_outputs = 1

# %%
n_outputs = 1
in_shape = (X.shape[1],X.shape[2])

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=in_shape))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
# model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
# model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
# model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))

model.add(Conv1D(filters=8, kernel_size=3, activation='relu'))
# model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
# model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
# model.add(Dense(10,activation='relu'))
model.add(Dense(n_outputs))

model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 398, 64)           1600
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 396, 64)           12352
# _________________________________________________________________
# dropout (Dropout)            (None, 396, 64)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 394, 64)           12352
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 392, 8)            1544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 392, 8)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 3137
# =================================================================
# Total params: 30,985
# Trainable params: 30,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = load_model('models/flexex_velocity_model_{}.hdf5'.format(window))

# %%
cnn_history=model.fit(X_train,y_train,epochs = 25,batch_size = 4000,validation_data = (X_test,y_test) )
# Out:
# Epoch 1/25
# 28/28 [==============================] - 13s 336ms/step - loss: 1.0097 - val_loss: 0.9892
# Epoch 2/25
# 28/28 [==============================] - 8s 288ms/step - loss: 1.0026 - val_loss: 0.9892
# Epoch 3/25
# 28/28 [==============================] - 8s 290ms/step - loss: 0.9916 - val_loss: 0.9473
# Epoch 4/25
# 28/28 [==============================] - 8s 294ms/step - loss: 0.9495 - val_loss: 0.9095
# Epoch 5/25
# 28/28 [==============================] - 8s 302ms/step - loss: 0.9117 - val_loss: 0.8737
# Epoch 6/25
# 28/28 [==============================] - 8s 299ms/step - loss: 0.8819 - val_loss: 0.8362
# Epoch 7/25
# 28/28 [==============================] - 9s 305ms/step - loss: 0.8573 - val_loss: 0.8760
# Epoch 8/25
# 28/28 [==============================] - 9s 318ms/step - loss: 0.8284 - val_loss: 0.8595
# Epoch 9/25
# 28/28 [==============================] - 9s 330ms/step - loss: 0.8116 - val_loss: 0.7767
# Epoch 10/25
# 28/28 [==============================] - 9s 334ms/step - loss: 0.7953 - val_loss: 0.7979
# Epoch 11/25
# 28/28 [==============================] - 9s 336ms/step - loss: 0.7757 - val_loss: 0.7375
# Epoch 12/25
# 28/28 [==============================] - 9s 334ms/step - loss: 0.7633 - val_loss: 0.7881
# Epoch 13/25
# 28/28 [==============================] - 10s 340ms/step - loss: 0.7426 - val_loss: 0.7223
# Epoch 14/25
# 28/28 [==============================] - 10s 357ms/step - loss: 0.7307 - val_loss: 0.6820
# Epoch 15/25
# 28/28 [==============================] - 10s 344ms/step - loss: 0.7350 - val_loss: 0.6762
# Epoch 16/25
# 28/28 [==============================] - 10s 359ms/step - loss: 0.7118 - val_loss: 0.6823
# Epoch 17/25
# 28/28 [==============================] - 10s 375ms/step - loss: 0.6909 - val_loss: 0.6542
# Epoch 18/25
# 28/28 [==============================] - 10s 359ms/step - loss: 0.6842 - val_loss: 0.6863
# Epoch 19/25
# 28/28 [==============================] - 11s 378ms/step - loss: 0.6753 - val_loss: 0.7112
# Epoch 20/25
# 28/28 [==============================] - 10s 363ms/step - loss: 0.6678 - val_loss: 0.6161
# Epoch 21/25
# 28/28 [==============================] - 10s 351ms/step - loss: 0.6661 - val_loss: 0.6044
# Epoch 22/25
# 28/28 [==============================] - 10s 362ms/step - loss: 0.6480 - val_loss: 0.5983
# Epoch 23/25
# 28/28 [==============================] - 11s 378ms/step - loss: 0.6398 - val_loss: 0.6848
# Epoch 24/25
# 28/28 [==============================] - 10s 360ms/step - loss: 0.6383 - val_loss: 0.5671
# Epoch 25/25
# 28/28 [==============================] - 10s 366ms/step - loss: 0.6252 - val_loss: 0.5571

# %%
model.save('models/flexex_velocity_model_{}.hdf5'.format(window))

# %%
import matplotlib.pyplot as plt
def plot_model(history):
#     plt.figure(figsize=(10,6))
#     plt.plot(history.history['root_mean_squared_error'][1:])
#     plt.plot(history.history['val_root_mean_squared_error'][1:])
#     plt.title('Model RMSE',size=20)
#     plt.ylabel('RMSE Loss',size=15)
#     plt.xlabel('Epochs', size=15)
#     plt.legend(['Training', 'Testing'], loc='best')
#     plt.show()
    
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss',size=20)
    plt.ylabel('Loss',size=15)
    plt.xlabel('Epochs',size=15)
    plt.legend(['Training', 'Testing'], loc='best')
    plt.show()

# %%
plot_model(cnn_history)

# %% [markdown]
# ## Model Testing

# %%
file = 'Subjects/Fazil/day_04_24_21/computed_Hammer.csv'
df = pd.read_csv(file,index_col=0)

# %%
X, y = prep_data_velocity(df,window,interval=10,Normalize=False,rms=False,angle_label ='Flexion_Angle')

# %%
X_mean = np.load('mean_std_flexex.npy')[0]
X_std = np.load('mean_std_flexex.npy')[1]
X_new = []
for x in tqdm(X):
    X_new.append((x-X_mean)/X_std)
X = np.array(X_new)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5360.0), HTML(value='')))

# %%
pred = model.predict(X)

# %%
plt.figure(figsize=(16,5))
plt.plot(pred)
plt.plot(y)
plt.title('True Velocity Vs Predicted Velocity',size=20)
plt.ylabel('Ang Velocity',size=15)
plt.xlabel('Time', size=15)
plt.legend(['Predicted', 'True'], loc='best')
plt.show()

# %%
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error
print('MSE Loss -',mean_squared_error(y,pred))
print('RMSE Loss -',mean_squared_error(y,pred,squared=False))
print('Pearson Correlation Coefficient -',pearsonr(y.flatten(),pred.flatten()))
# Out:
# MSE Loss - 0.5903041024204547
# RMSE Loss - 0.7683125031004342
# Pearson Correlation Coefficient - (0.6472600413047008, 0.0)
