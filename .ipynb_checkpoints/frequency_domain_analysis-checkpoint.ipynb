# %% [markdown]
# # Frequency Domain Analysis

# %%
from scipy.fft import rfft, rfftfreq
from matplotlib import pyplot as plt
from math import sin,cos
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from numpy.fft import fft,rfft
from scipy import fftpack
from Data_preparation_Library import *
from random import shuffle
from keras.models import load_model

# %%
def single_analyse(y,rms_win=200):
    fig, ax = plt.subplots(3,1,figsize=(16,12))
    ax[0].title.set_text('Raw EMG')
    ax[0].plot(y)
    
    ax[1].title.set_text('RMS EMG')
    ax[1].plot(rms(y,rms_win))
    
#     scaler = MinMaxScaler(feature_range=(-1,1))
#     mx = scaler.fit_transform(y.reshape(-1,1))
#     ax[2].title.set_text('MinMax EMG')
#     ax[2].plot(mx)
    
    ax[2].title.set_text('Freaquency Domain EMG')
    spec,freq,line = ax[2].magnitude_spectrum(y,Fs=2000)
    gg = np.matmul(spec.reshape(-1,1),np.transpose(freq.reshape(-1,1)))

# %%
def window_analyse(y,rms_win=200):
    window = len(y)
    fig, ax = plt.subplots(3,1,figsize=(16,12))
    ax[0].title.set_text('Raw EMG')
    ax[0].plot(y)
    
    ax[1].title.set_text('RMS EMG')
    ax[1].plot(rms_df(y,rms_win))
    
#     scaler = MinMaxScaler(feature_range=(-1,1))
#     mx = scaler.fit_transform(y)
#     ax[2].title.set_text('MinMax EMG')
#     ax[2].plot(mx)
    
    ax[2].title.set_text('Freaquency Domain EMG')
    for i in range(y.shape[1]):
        x = y[:,i]
        spec,freq,line = ax[2].magnitude_spectrum(x,2000)

# %%
def count(y):
    s0 = 0
    s1 = 0
    s2 = 0
    for arr in y:
        if arr[0]==1:
            s0 = s0+1
        if arr[1]==1:
            s1 = s1+1
        if arr[2]==1:
            s2 = s2+1
    ls = [s0,s1,s2]
    for i in range(3):
        print(i,'-',ls[i],'[',ls[i]*100/len(y),'%]')

# %%
def freaq_window(data,Fs=2000):
    spec_list = []
    for i in range(data.shape[1]):
        y = data[:,i]
        spec,freq,line = plt.magnitude_spectrum(y,Fs)
        spec_list.append(spec)
    X = np.array(spec_list[0])
    for x in spec_list[1:]:
        X = np.vstack((X,np.array(x)))
    return np.transpose(X)

# %%
file = 'Subjects/Fazil/day_04_24_21/computed_Hammer02.csv'
angle_lables = ['Pronation_Angle','Flexion_Angle',  'Radial_Angle','Elbow_Joint_Angle']
emg_labels = ['EMG1','EMG2','EMG3','EMG4','EMG5','EMG6','EMG7','EMG8']
main_df = pd.read_csv(file,index_col=0)
main_df[angle_lables].plot(figsize=(16,5),title=file,grid=True,xticks=np.linspace(main_df.index[0],main_df.index[-1],20))
# Out:
# <AxesSubplot:title={'center':'Subjects/Fazil/day_04_24_21/computed_Hammer02.csv'}>

# %%
df = main_df

# %% [markdown]
# # Signal Analysis

# %%
X, y = prep_data_DTM(df,200,interval=5,Normalize=False,plot=True,angle_thresh=0.008,rms=False)
# Out:
# 0 -> 58.698884758364315 %
# 1 -> 12.75092936802974 %
# 2 -> 28.550185873605948 %

# %%
emg1 = df['EMG1']
y = np.array(emg1)
df[angle_lables[1:3]].plot(figsize=(15,5),xticks=np.linspace(df.index[0],df.index[-1],15),grid=True)
plt.show()
df[emg_labels].plot(figsize=(15,5),xticks=np.linspace(df.index[0],df.index[-1],15),grid=True)
plt.show()
df['EMG1'].plot(figsize=(15,5),xticks=np.linspace(df.index[0],df.index[-1],15),grid=True)
# Out:
# <AxesSubplot:>

# %%
single_analyse(y,20)

# %% [markdown]
# ## Window Signal Analysis

# %%
emg = df[emg_labels]
y_win = np.array(emg)

# %%
window_analyse(y_win,20)

# %% [markdown]
# ## Neural Networks

# %%
X, y = prep_data_DTM(df,400,interval=5,Normalize=False,angle_thresh=0.008)

# %%
freq_X = []
scaler= MinMaxScaler(feature_range=(0,1))
for i in tqdm(range(X.shape[0])):
    freq_X.append(scaler.fit_transform(freaq_window(X[i])))
X = np.array(freq_X)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10720.0), HTML(value='')))

# %%
count(y)
# Out:
# 0 - 6285 [ 58.62873134328358 %]
# 1 - 1628 [ 15.186567164179104 %]
# 2 - 2807 [ 26.184701492537314 %]

# %% [markdown]
# ### Sklearn

# %%
new_X = []
for x in X:
    new_X.append(x.flatten())
X = np.array(new_X)
y = np.array([ele.argmax() for ele in y])
print(X.shape,y.shape)
# Out:
# (10720, 1608) (10720,)

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='adam', 
                    hidden_layer_sizes=(5, 2), 
                    random_state=1,
                    max_iter=20000,
                    verbose=True)

# %%
clf.fit(X, y)
# Out:
# Iteration 1, loss = 1.30570497
# Iteration 2, loss = 1.19422881
# Iteration 3, loss = 1.10502007
# Iteration 4, loss = 1.01385637
# Iteration 5, loss = 0.92237806
# Iteration 6, loss = 0.83969490
# Iteration 7, loss = 0.77920187
# Iteration 8, loss = 0.74370948
# Iteration 9, loss = 0.72200032
# Iteration 10, loss = 0.70639337
# Iteration 11, loss = 0.69283382
# Iteration 12, loss = 0.68138038
# Iteration 13, loss = 0.67080407
# Iteration 14, loss = 0.66067819
# Iteration 15, loss = 0.65174061
# Iteration 16, loss = 0.64371199
# Iteration 17, loss = 0.63511782
# Iteration 18, loss = 0.62752588
# Iteration 19, loss = 0.61970188
# Iteration 20, loss = 0.61199262
# Iteration 21, loss = 0.60474933
# Iteration 22, loss = 0.59655043
# Iteration 23, loss = 0.58852439
# Iteration 24, loss = 0.58031941
# Iteration 25, loss = 0.57219572
# Iteration 26, loss = 0.56430506
# Iteration 27, loss = 0.55387162
# Iteration 28, loss = 0.54231286
# Iteration 29, loss = 0.53015876
# Iteration 30, loss = 0.51690194
# Iteration 31, loss = 0.50411503
# Iteration 32, loss = 0.48452129
# Iteration 33, loss = 0.46574816
# Iteration 34, loss = 0.44451856
# Iteration 35, loss = 0.42208545
# Iteration 36, loss = 0.40017527
# Iteration 37, loss = 0.37822114
# Iteration 38, loss = 0.35740555
# Iteration 39, loss = 0.33791458
# Iteration 40, loss = 0.32141929
# Iteration 41, loss = 0.30574142
# Iteration 42, loss = 0.29038092
# Iteration 43, loss = 0.27706465
# Iteration 44, loss = 0.26467199
# Iteration 45, loss = 0.25129956
# Iteration 46, loss = 0.24036873
# Iteration 47, loss = 0.23095377
# Iteration 48, loss = 0.22185574
# Iteration 220, loss = 0.05835513
# Iteration 221, loss = 0.05889506
# Iteration 222, loss = 0.06089705
# Iteration 223, loss = 0.05981157
# Iteration 224, loss = 0.05707787
# Iteration 225, loss = 0.06063177
# Iteration 226, loss = 0.05881194
# Iteration 227, loss = 0.05872785
# Iteration 228, loss = 0.05844490
# Iteration 229, loss = 0.05945332
# Iteration 230, loss = 0.06057550
# Iteration 231, loss = 0.05855334
# Iteration 232, loss = 0.05779069
# Iteration 233, loss = 0.05778126
# Iteration 234, loss = 0.05632801
# Iteration 235, loss = 0.05835056
# Iteration 236, loss = 0.05777480
# Iteration 237, loss = 0.05651404
# Iteration 238, loss = 0.05748576
# Iteration 239, loss = 0.05629952
# Iteration 240, loss = 0.05724263
# Iteration 241, loss = 0.05599833
# Iteration 242, loss = 0.05614958
# Iteration 243, loss = 0.05609664
# Iteration 244, loss = 0.05851335
# Iteration 245, loss = 0.05580799
# Iteration 246, loss = 0.05537197
# Iteration 247, loss = 0.05649378
# Iteration 248, loss = 0.05537760
# Iteration 249, loss = 0.05669277
# Iteration 250, loss = 0.05767529
# Iteration 251, loss = 0.05805935
# Iteration 252, loss = 0.05913749
# Iteration 253, loss = 0.05739229
# Iteration 254, loss = 0.05551997
# Iteration 255, loss = 0.05477145
# Iteration 256, loss = 0.05548733
# Iteration 257, loss = 0.05527313
# Iteration 258, loss = 0.05495171
# Iteration 259, loss = 0.05480089
# Iteration 260, loss = 0.05607840
# Iteration 261, loss = 0.05658040
# Iteration 262, loss = 0.05568184
# Iteration 263, loss = 0.05375065
# Iteration 264, loss = 0.05671754
# Iteration 265, loss = 0.05550076
# Iteration 266, loss = 0.05562126
# Iteration 267, loss = 0.05506271
# Iteration 268, loss = 0.05483334
# Iteration 269, loss = 0.05390783
# Iteration 270, loss = 0.05822449
# Iteration 271, loss = 0.05947257
# Iteration 272, loss = 0.05450267
# Iteration 273, loss = 0.05388855
# Iteration 274, loss = 0.05312789
# Iteration 275, loss = 0.05353393
# Iteration 276, loss = 0.05405453
# Iteration 277, loss = 0.05397662
# Iteration 278, loss = 0.05351185
# Iteration 279, loss = 0.05569257
# Iteration 280, loss = 0.05325224
# Iteration 281, loss = 0.05252755
# Iteration 282, loss = 0.05537081
# Iteration 283, loss = 0.05625335
# Iteration 284, loss = 0.05394473
# Iteration 285, loss = 0.05313880
# Iteration 286, loss = 0.05327615
# Iteration 287, loss = 0.05295638
# Iteration 288, loss = 0.05328740
# Iteration 289, loss = 0.05347434
# Iteration 290, loss = 0.05488641
# Iteration 291, loss = 0.05630773
# Iteration 292, loss = 0.05274565
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(5, 2), max_iter=20000, random_state=1,
#               verbose=True)

# %%
pred = clf.predict([X[0]])

# %%
acc = 0
for i in range(len(pred)):
    if pred[i]==y[i]:
        acc = acc + 1
acc = acc/len(y)
print('Acc-',acc)
# Out:
# Acc- 9.328358208955224e-05

# %% [markdown]
# ### Keras

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.optimizers import SGD
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
n_outputs = 2

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X.shape[1],X.shape[2])))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
# model.add(Dense(64,activation='relu'))
model.add(Dense(n_outputs, activation='softmax'))

opt = SGD(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# checkpoint
filepath="weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

model.summary()

# %%
# Fit the model
model.fit(X, y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
