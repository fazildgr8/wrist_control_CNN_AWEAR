# %%
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
import pandas as pd
from scipy import signal
from Data_preparation_Library import *
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
file = 'sample_computed_data.csv'
emg_labels = ['EMG1','EMG2','EMG3','EMG4','EMG5','EMG6','EMG7','EMG8']
angle_lables = ['Pronation_Angle'] # 'Pronation_Angle','Flexion_Angle',  'Radial_Angle','Elbow_Joint_Angle'
df = pd.read_csv(file,index_col=0)
df[angle_lables].plot(figsize=(16,5),title=file,grid=True,xticks=np.linspace(0,len(df),5))
emg_df = df[emg_labels]
arr = np.array(df['Pronation_Angle'])

b,a = signal.butter(1, 1,fs=2000)
arr = signal.lfilter(b, a,arr)

# arr = np.rad2deg(np.unwrap(np.deg2rad(arr)))
arr = np.diff(list(arr))
arr = arr/(1/2000)
b,a = signal.butter(1, 1,fs=2000)
arr = signal.lfilter(b, a,arr)
# arr = arr/df.index

pd.DataFrame(arr).plot(figsize=(16,5),title='Velocity',grid=True,xticks=np.linspace(0,len(df),5))
emg_df.plot(figsize=(16,5),title='sEMG Data')
# Out:
# <AxesSubplot:title={'center':'sEMG Data'}>

# %%
X,y = prep_data_velocity(df,250,interval=10,Normalize=False,rms=False,angle_label ='Pronation_Angle')
X.shape
# Out:
# (9175, 250, 8)

# %%
X_mean = np.zeros(X[0].shape)
for x in X:
    X_mean = X_mean + x
X_mean = X_mean/X.shape[0]
X_std = np.sqrt(variance(X))
np.save('mean_std',np.array([X_mean,X_std]))

# %%
X_new = []
for x in tqdm(X):
    X_new.append((x-X_mean)/X_std)
X = np.array(X_new)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9175.0), HTML(value='')))

# %%
y_mean = 0
for v in y:
  y_mean = y_mean + v
y_mean = y_mean/y.shape[0]
y_std = np.sqrt(variance(y))
np.save('vel_mean_std',np.array([y_mean,y_std]))

# %%
scaler = StandardScaler()
y = scaler.fit_transform(y.reshape(y.shape[0],1))

# %%
plt.plot(y)

# %%
y_new = []
for v in tqdm(y):
    y_new.append((v-y_mean)/y_std)
y = np.array(y_new)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9175.0), HTML(value='')))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow import keras

# %%
n_outputs = 1
in_shape = (X.shape[1],X.shape[2])

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=in_shape))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Conv1D(filters=26, kernel_size=3, activation='relu'))

# model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
# model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
# model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
# model.add(Dense(64,activation='relu'))
model.add(Dense(n_outputs))

model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 248, 64)           1600
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 246, 32)           6176
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 244, 26)           2522
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 244, 26)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6344)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6345
# =================================================================
# Total params: 16,643
# Trainable params: 16,643
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X,y,epochs=100,validation_split=0.2,shuffle=True,batch_size=1000)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0197 - val_loss: 2.5729
# Epoch 2/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0209 - val_loss: 2.5855
# Epoch 3/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0180 - val_loss: 2.5666
# Epoch 4/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0181 - val_loss: 2.5378
# Epoch 5/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0185 - val_loss: 2.6181
# Epoch 6/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0193 - val_loss: 2.5703
# Epoch 7/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0186 - val_loss: 2.5467
# Epoch 8/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0195 - val_loss: 2.5112
# Epoch 9/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0193 - val_loss: 2.5445
# Epoch 10/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0181 - val_loss: 2.5407
# Epoch 11/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0187 - val_loss: 2.5505
# Epoch 12/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0174 - val_loss: 2.5055
# Epoch 13/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0194 - val_loss: 2.5259
# Epoch 14/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0171 - val_loss: 2.5421
# Epoch 15/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0176 - val_loss: 2.5246
# Epoch 16/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0192 - val_loss: 2.6223
# Epoch 17/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0196 - val_loss: 2.6213
# Epoch 18/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0217 - val_loss: 2.5439
# Epoch 19/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0189 - val_loss: 2.5483
# Epoch 20/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0173 - val_loss: 2.5610
# Epoch 21/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0169 - val_loss: 2.5028
# Epoch 22/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0205 - val_loss: 2.4846
# Epoch 23/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0208 - val_loss: 2.4958
# Epoch 24/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0211 - val_loss: 2.5542
# Epoch 25/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0185 - val_loss: 2.5477
# Epoch 26/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0168 - val_loss: 2.5357
# Epoch 27/100
# 8/8 [==============================] - ETA: 0s - loss: 0.017 - 0s 26ms/step - loss: 0.0173 - val_loss: 2.5481
# Epoch 28/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0168 - val_loss: 2.5315
# Epoch 29/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0168 - val_loss: 2.5448
# Epoch 30/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0165 - val_loss: 2.5301
# Epoch 31/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0166 - val_loss: 2.5040
# Epoch 32/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0173 - val_loss: 2.5457
# Epoch 33/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0179 - val_loss: 2.5739
# Epoch 34/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0171 - val_loss: 2.5540
# Epoch 35/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0185 - val_loss: 2.5076
# Epoch 36/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0182 - val_loss: 2.4973
# Epoch 37/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0184 - val_loss: 2.5319
# Epoch 38/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0162 - val_loss: 2.5521
# Epoch 39/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0156 - val_loss: 2.5236
# Epoch 40/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0162 - val_loss: 2.5435
# Epoch 41/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0157 - val_loss: 2.5739
# Epoch 42/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0174 - val_loss: 2.4989
# Epoch 43/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0169 - val_loss: 2.5393
# Epoch 44/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0156 - val_loss: 2.5330
# Epoch 45/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0156 - val_loss: 2.5463
# Epoch 46/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0154 - val_loss: 2.5592
# Epoch 47/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0161 - val_loss: 2.5440
# Epoch 48/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0155 - val_loss: 2.5550
# Epoch 49/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0159 - val_loss: 2.4916
# Epoch 50/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0161 - val_loss: 2.4954
# Epoch 51/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0169 - val_loss: 2.5594
# Epoch 52/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0163 - val_loss: 2.5518
# Epoch 53/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0158 - val_loss: 2.5331
# Epoch 54/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0153 - val_loss: 2.5303
# Epoch 55/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0162 - val_loss: 2.5376
# Epoch 56/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0152 - val_loss: 2.5454
# Epoch 57/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0149 - val_loss: 2.5269
# Epoch 58/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0152 - val_loss: 2.5971
# Epoch 59/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0200 - val_loss: 2.5452
# Epoch 60/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0151 - val_loss: 2.5452
# Epoch 61/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0155 - val_loss: 2.4790
# Epoch 62/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0165 - val_loss: 2.5264
# Epoch 63/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0170 - val_loss: 2.5304
# Epoch 64/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0151 - val_loss: 2.6259
# Epoch 65/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0191 - val_loss: 2.5652
# Epoch 66/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0168 - val_loss: 2.5011
# Epoch 67/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0150 - val_loss: 2.4964
# Epoch 68/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0148 - val_loss: 2.5016
# Epoch 69/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0168 - val_loss: 2.5670
# Epoch 70/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0181 - val_loss: 2.5896
# Epoch 71/100
# 8/8 [==============================] - ETA: 0s - loss: 0.016 - 0s 25ms/step - loss: 0.0160 - val_loss: 2.5503
# Epoch 72/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0147 - val_loss: 2.5186
# Epoch 73/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0149 - val_loss: 2.5466
# Epoch 74/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0143 - val_loss: 2.5158
# Epoch 75/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0146 - val_loss: 2.5232
# Epoch 76/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0150 - val_loss: 2.5250
# Epoch 77/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0150 - val_loss: 2.5614
# Epoch 78/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0157 - val_loss: 2.6137
# Epoch 79/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0170 - val_loss: 2.5475
# Epoch 80/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0157 - val_loss: 2.5390
# Epoch 81/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0158 - val_loss: 2.5001
# Epoch 82/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0147 - val_loss: 2.5121
# Epoch 83/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0140 - val_loss: 2.5316
# Epoch 84/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0142 - val_loss: 2.5122
# Epoch 85/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0147 - val_loss: 2.4967
# Epoch 86/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0159 - val_loss: 2.5214
# Epoch 87/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0163 - val_loss: 2.5956
# Epoch 88/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0159 - val_loss: 2.5499
# Epoch 89/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0146 - val_loss: 2.4994
# Epoch 90/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0153 - val_loss: 2.5425
# Epoch 91/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0135 - val_loss: 2.5353
# Epoch 92/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0140 - val_loss: 2.5041
# Epoch 93/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0139 - val_loss: 2.5120
# Epoch 94/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0144 - val_loss: 2.5548
# Epoch 95/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0147 - val_loss: 2.4970
# Epoch 96/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0157 - val_loss: 2.5090
# Epoch 97/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0143 - val_loss: 2.5607
# Epoch 98/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0167 - val_loss: 2.5638
# Epoch 99/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0152 - val_loss: 2.5074
# Epoch 100/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.0154 - val_loss: 2.5495

# %%
pred = model.predict(X)
true = y
plt.figure(figsize=(16,10))
plt.plot(true)
plt.figure(figsize=(16,10))
plt.plot(pred)

# %%
def get_velocity(arr,sr):
    dt = 1/sr
    diff = np.diff(arr)
    diff = diff/dt
    return diff
